# %%
import h5py
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import os
import csv

# %%
def read_hdf5(filename):
    # Open the HDF5 file and read the data
    with h5py.File(filename, "r") as f:
        # Access the 'OpenData' dataset and transpose it as needed
        sample_dataset = f['OpenData'][:].transpose()

        # Check the dataset shape
        print("Dataset shape:", sample_dataset.shape)

        # Determine in-control or out-of-control status based on IDbulkLayer
        IDbulkLayer = sample_dataset[:, 7]
        unique_values = np.unique(IDbulkLayer, return_counts=False)
        status = ["in control" if val == 1 else "out of control" for val in unique_values]

        # Print status
        print("Status:", status)

        # Extract variables for plotting
        X_variable = sample_dataset[:, 0]
        Y_variable = sample_dataset[:, 1]
        SignalInGaAs = sample_dataset[:, 6]

        # Create a 3D scatter plot
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        scatter = ax.scatter3D(X_variable, Y_variable, SignalInGaAs, c=SignalInGaAs, cmap='viridis')
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('SignalInGaAs')

        # Optional: Add a color bar for the SignalInGaAs scale
        fig.colorbar(scatter, ax=ax, label='SignalInGaAs')

        # Save the plot as a JPG file
        plot_filename = filename.replace('.hdf5', '.jpg')  # Name it based on the HDF5 filename
        plt.savefig(plot_filename, format="jpg")

        # Show the plot
        #plt.show()

    # Return the status and the path to the saved plot
    return status, plot_filename

# %%
filename = "/content/layer89.hdf5"
status, plot_filename = read_hdf5(filename)

print("Control Status:", status)
print("Plot saved as:", plot_filename)

# %%
def read_hdf5(filename, image_folder):
    # Open the HDF5 file and read the data
    with h5py.File(filename, "r") as f:
        sample_dataset = f['OpenData'][:].transpose()

        # Determine in-control or out-of-control status based on IDbulkLayer
        IDbulkLayer = sample_dataset[:, 7]
        unique_values = np.unique(IDbulkLayer, return_counts=False)
        status = ["in control" if val == 1 else "out of control" for val in unique_values]

        # Extract variables for plotting
        X_variable = sample_dataset[:, 0]
        Y_variable = sample_dataset[:, 1]
        SignalInGaAs = sample_dataset[:, 6]

        # Create a 3D scatter plot
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        scatter = ax.scatter3D(X_variable, Y_variable, SignalInGaAs, c=SignalInGaAs, cmap='viridis')
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('SignalInGaAs')

        # Optional: Add a color bar for the SignalInGaAs scale
        #fig.colorbar(scatter, ax=ax, label='SignalInGaAs')

        # Define the image filename and save the plot in the 'all_images' folder
        plot_filename = os.path.join(image_folder, os.path.basename(filename).replace('.hdf5', '.jpg'))
        plt.savefig(plot_filename, format="jpg")
        plt.close(fig)

    return status, plot_filename

# Main function to process all files in a folder
def process_hdf5_folder(folder_path, output_csv):
    # Create the 'all_images' subfolder within folder_path
    image_folder = os.path.join(folder_path, "all_images")
    os.makedirs(image_folder, exist_ok=True)

    results = []

    # Process each .hdf5 file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".hdf5"):
            full_path = os.path.join(folder_path, filename)
            file_name_no_ext = os.path.splitext(filename)[0]  # Remove the .hdf5 extension

            # Get status and save the plot in 'all_images' folder
            status, plot_filename = read_hdf5(full_path, image_folder)

            # Save filename (without extension) and status to results
            results.append([file_name_no_ext, status])

    # Write results to a CSV file
    with open(output_csv, mode='w', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(["File Name", "Status"])  # Header
        writer.writerows(results)

    print(f"Results saved to {output_csv}")
    print(f"All images saved in folder: {image_folder}")

# Example usage
folder_path = "/content/all_hdf5_data"  # Replace with your folder path
output_csv = "/content/status_results.csv"
process_hdf5_folder(folder_path, output_csv)
# Out:
# Results saved to /content/status_results.csv
# All images saved in folder: /content/all_hdf5_data/all_images

# %%
# !zip -r /content/all_images.zip /content/all_hdf5_data/all_images
# Out:
#   adding: content/all_hdf5_data/all_images/ (stored 0%)
#   adding: content/all_hdf5_data/all_images/layer74.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer334.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer138.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer124.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer84.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer190.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer47.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer338.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer4.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer317.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer202.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer227.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer296.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer32.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer206.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer279.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer185.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer287.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer357.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer62.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer371.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer292.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer104.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer159.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer54.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer358.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer346.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer57.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer217.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer11.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer173.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer77.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer335.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer70.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer250.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer189.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer122.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer23.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer179.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer230.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer354.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer130.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer112.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer224.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer191.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer99.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer326.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer176.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer345.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer18.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer364.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer339.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer29.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer135.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer25.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer151.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer305.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer24.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer251.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer103.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer192.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer368.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer111.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer275.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer321.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer226.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer114.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer241.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer320.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer200.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer39.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer342.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer152.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer220.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer166.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer35.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer348.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer269.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer194.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer3.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer263.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer16.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer210.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer309.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer66.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer294.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer65.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer234.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer277.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer223.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer341.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer331.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer379.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer132.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer258.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer193.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer105.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer172.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer363.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer236.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer186.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer45.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer235.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer83.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer154.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer332.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer322.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer370.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer311.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer53.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer195.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer52.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer276.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer36.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer221.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer303.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer169.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer247.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer349.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer361.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer376.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer158.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer98.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer5.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer102.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer378.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer2.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer12.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer286.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer208.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer19.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer336.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer175.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer278.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer80.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer64.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer69.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer187.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer268.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer121.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer97.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer13.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer295.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer248.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer308.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer233.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer113.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer360.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer72.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer288.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer350.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer344.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer61.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer225.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer243.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer267.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer71.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer330.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer231.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer281.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer108.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer82.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer211.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer329.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer129.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer21.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer300.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer148.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer259.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer353.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer41.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer274.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer365.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer86.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer213.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer304.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer131.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer280.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer96.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer134.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer203.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer101.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer9.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer337.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer328.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer43.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer79.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer283.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer372.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer87.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer128.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer116.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer85.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer75.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer313.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer297.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer78.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer356.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer162.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer242.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer153.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer262.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer212.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer306.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer240.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer76.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer266.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer307.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer49.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer367.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer127.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer374.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer107.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer42.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer214.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer81.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer302.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer290.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer249.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer298.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer183.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer140.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer46.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer347.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer89.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer375.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer137.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer301.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer68.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer327.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer48.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer28.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer318.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer118.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer106.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer125.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer237.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer38.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer373.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer115.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer260.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer188.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer219.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer205.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer1.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer222.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer284.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer355.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer20.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer271.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer168.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer123.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer343.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer44.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer147.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer255.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer156.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer319.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer157.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer366.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer377.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer60.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer170.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer232.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer17.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer119.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer201.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer59.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer362.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer88.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer177.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer145.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer120.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer164.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer26.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer196.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer34.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer93.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer244.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer165.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer27.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer316.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer270.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer63.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer14.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer141.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer245.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer56.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer181.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer33.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer323.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer178.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer73.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer199.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer215.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer256.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer51.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer155.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer289.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer8.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer333.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer369.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer204.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer273.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer239.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer197.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer161.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer7.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer100.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer37.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer324.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer160.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer299.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer58.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer94.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer229.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer171.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer40.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer174.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer67.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer110.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer10.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer257.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer149.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer95.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer117.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer92.jpg (deflated 10%)
#   adding: content/all_hdf5_data/all_images/layer150.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer285.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer315.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer139.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer31.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer293.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer209.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer265.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer50.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer246.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer340.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer146.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer90.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer144.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer91.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer55.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer291.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer15.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer253.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer133.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer218.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer180.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer264.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer22.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer228.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer143.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer126.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer252.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer142.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer310.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer282.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer6.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer182.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer184.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer207.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer198.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer216.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer136.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer325.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer351.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer163.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer167.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer254.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer261.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer30.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer109.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer312.jpg (deflated 12%)
#   adding: content/all_hdf5_data/all_images/layer352.jpg (deflated 14%)
#   adding: content/all_hdf5_data/all_images/layer238.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer359.jpg (deflated 13%)
#   adding: content/all_hdf5_data/all_images/layer272.jpg (deflated 11%)
#   adding: content/all_hdf5_data/all_images/layer314.jpg (deflated 11%)

# %%
from google.colab import files
files.download("/content/all_images.zip")
